# %% [markdown]
# Curso hugging face
#
# https://huggingface.co/learn/nlp-course/pt/chapter0/1?fw=pt

# %% [markdown]
# fine tunning with whisper
#
# https://youtu.be/anplUNnkM68?si=V8ZtY4kwz3mj4bQZ
#
# https://github.com/huggingface/community-events/tree/main/whisper-fine-tuning-event#whisper-fine-tuning-event-
#
# https://huggingface.co/blog/fine-tune-whisper
#
# https://medium.com/@unlikely_ai/fine-tuning-and-deployment-of-custom-asr-models-9e0eb5c45496
#
# Conjunto de dados de audio
#
# https://huggingface.co/datasets?task_categories=task_categories:automatic-speech-recognition&sort=downloads
#
# https://medium.com/@renatoleal/datasets-de-%C3%A1udio-em-portugu%C3%AAs-
#
# Modelos
#
# https://huggingface.co/models?search=openai/whisper

# %% [markdown]
# Criar datasets
#
# https://huggingface.co/blog/audio-datasets
#
# https://huggingface.co/docs/datasets/audio_dataset

# %% [markdown]
# Quais as diferenças?
#   -> Wav2vec2 X whisper
