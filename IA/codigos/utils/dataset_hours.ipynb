# %%
# !pip3 install torchaudio
# Out:
# Collecting torchaudio
#   Downloading torchaudio-2.6.0-cp312-cp312-manylinux1_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: torch==2.6.0 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torchaudio) (2.6.0)
# Requirement already satisfied: filelock in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (4.12.2)
# Requirement already satisfied: networkx in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (3.4.2)
# Requirement already satisfied: jinja2 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (3.1.5)
# Requirement already satisfied: fsspec in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (3.2.0)
# Requirement already satisfied: setuptools in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from torch==2.6.0->torchaudio) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from sympy==1.13.1->torch==2.6.0->torchaudio) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/bruno-dev/anaconda3/envs/fine_test/lib/python3.12/site-packages (from jinja2->torch==2.6.0->torchaudio) (2.1.5)
# Downloading torchaudio-2.6.0-cp312-cp312-manylinux1_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 20.9 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: torchaudio
# Successfully installed torchaudio-2.6.0

# %%
from datasets import load_dataset
import torchaudio

# %%
def calculate_hours(dataset):

    full_duration = 0.0

    for example in dataset:
        audio = example["audio"]
        full_duration += audio["array"].shape[0] / audio["sampling_rate"]  
    return full_duration

# %%
dataset = load_dataset("brunopbb/ufcg-labmet-fala-texto-main")

train = dataset['train']
test = dataset['test']

duration_test = calculate_hours(test)
duration_train = calculate_hours(train)



min_full_duration = (duration_test + duration_train) / 60

print(f'duração train: {(duration_train / 60):.4f}')
print(f'duração test: {(duration_test / 60):.4f}')
print(f"Duração total do dataset: {min_full_duration:.4f} minutos")
# Out:
# duração train: 51.5134
# duração test: 16.0806
# Duração total do dataset: 67.5941 minutos
